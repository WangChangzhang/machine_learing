# %%
import mglearn
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
iris = load_iris()

X_train,X_test,y_train,y_test = train_test_split(iris['data'], iris['target'], random_state=0)
X_data = pd.DataFrame(data=X_train, columns=iris.feature_names)
pd.plotting.scatter_matrix(X_data,alpha=0.8,figsize=(20,20),marker='O',c=y_train,diagonal='hist',cmap=mglearn.cm3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002057B8EAE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057B9BC240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057B9F91D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BA331D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002057BA3BFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BA3BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BACB8D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BD448D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002057BD808D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BDB4320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BDEC320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BE247F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002057BE5CD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BE89A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BEC9320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002057BF04390>]],
#       dtype=object)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
X_new = np.array([[5, 2.9, 1, 0.2]])
print(X_new.shape)
predict = knn.predict(X_new)
print(predict)
# Out:
# (1, 4)
# [0]

# %%
knn.score(X_test, y_test)
# Out:
# 0.9736842105263158
